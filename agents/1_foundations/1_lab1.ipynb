# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')

if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:8]}")
else:
    print("Anthropic API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Anthropic API Key exists and begins sk-ant-a

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

import anthropic

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

client = anthropic.Anthropic()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = client.messages.create(
    model="claude-3-haiku",
    max_tokens=1000,
    messages=messages
)

print(response.content[0].text)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = client.messages.create(
    model="claude-3-haiku",
    max_tokens=1000,
    messages=messages
)
  

question = response.content[0].text

print(question)
# Out:
# If you have 12 balls that look identical, but one weighs slightly different from the other 11, what is the minimum number of weighings needed using a balance scale to identify which ball is different AND determine whether it's heavier or lighter than the others?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = client.messages.create(
    model="claude-3-haiku",
    max_tokens=1000,
    messages=messages
)

answer = response.content[0].text
print(answer)
# Out:
# I need to find the minimum number of weighings to both identify the different ball and determine if it's heavier or lighter.
#
# Let me think about this systematically using information theory and the process of elimination.
#
# **Information Analysis:**
# - I have 12 balls, where 11 are identical and 1 is different
# - The different ball could be any of the 12 balls AND could be either heavier or lighter
# - Total possible outcomes: 12 balls × 2 states (heavy/light) = 24 possibilities
# - Each weighing with a balance scale gives 3 possible outcomes: left heavier, right heavier, or balanced
# - With n weighings, I can distinguish at most 3ⁿ possibilities
#
# Since 3² = 9 < 24 and 3³ = 27 > 24, I need at least 3 weighings theoretically.
#
# **The 3-Weighing Solution:**
#
# **First weighing:** Divide into three groups of 4 balls each
# - Group A (balls 1,2,3,4) vs Group B (balls 5,6,7,8)
# - Group C (balls 9,10,11,12) stays aside
#
# **Case 1: A = B (balanced)**
# The different ball is in Group C (9,10,11,12)
#
# **Second weighing:** Compare (9,10) vs (1,2) [using known normal balls]
# - If balanced: different ball is 11 or 12
# - If unbalanced: different ball is 9 or 10, and we know if it's heavy or light
#
# **Third weighing:** Test the remaining candidates to identify which specific ball and confirm heavy/light.
#
# **Case 2: A > B (A heavier than B)**
# The different ball is either:
# - A heavy ball in group A, OR
# - A light ball in group B
#
# **Second weighing:** Compare (1,2,5) vs (3,6,9)
# This strategic regrouping will create different outcomes depending on where the different ball is located.
#
# **Third weighing:** Based on the second weighing result, test specific balls to pinpoint the exact ball and its weight difference.
#
# **Case 3: A < B**
# Similar logic to Case 2, but reversed.
#
# The key insight is that each weighing must be designed to maximally divide the remaining possibilities into three roughly equal groups.
#
# **Answer: The minimum number of weighings needed is 3.**
#
# This is both the theoretical minimum (since 3² < 24 ≤ 3³) and achievable in practice with the right strategy.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# I need to find the minimum number of weighings to both identify the different ball and determine if it's heavier or lighter.
#
# Let me think about this systematically using information theory and the process of elimination.
#
# **Information Analysis:**
# - I have 12 balls, where 11 are identical and 1 is different
# - The different ball could be any of the 12 balls AND could be either heavier or lighter
# - Total possible outcomes: 12 balls × 2 states (heavy/light) = 24 possibilities
# - Each weighing with a balance scale gives 3 possible outcomes: left heavier, right heavier, or balanced
# - With n weighings, I can distinguish at most 3ⁿ possibilities
#
# Since 3² = 9 < 24 and 3³ = 27 > 24, I need at least 3 weighings theoretically.
#
# **The 3-Weighing Solution:**
#
# **First weighing:** Divide into three groups of 4 balls each
# - Group A (balls 1,2,3,4) vs Group B (balls 5,6,7,8)
# - Group C (balls 9,10,11,12) stays aside
#
# **Case 1: A = B (balanced)**
# The different ball is in Group C (9,10,11,12)
#
# **Second weighing:** Compare (9,10) vs (1,2) [using known normal balls]
# - If balanced: different ball is 11 or 12
# - If unbalanced: different ball is 9 or 10, and we know if it's heavy or light
#
# **Third weighing:** Test the remaining candidates to identify which specific ball and confirm heavy/light.
#
# **Case 2: A > B (A heavier than B)**
# The different ball is either:
# - A heavy ball in group A, OR
# - A light ball in group B
#
# **Second weighing:** Compare (1,2,5) vs (3,6,9)
# This strategic regrouping will create different outcomes depending on where the different ball is located.
#
# **Third weighing:** Based on the second weighing result, test specific balls to pinpoint the exact ball and its weight difference.
#
# **Case 3: A < B**
# Similar logic to Case 2, but reversed.
#
# The key insight is that each weighing must be designed to maximally divide the remaining possibilities into three roughly equal groups.
#
# **Answer: The minimum number of weighings needed is 3.**
#
# This is both the theoretical minimum (since 3² < 24 ≤ 3³) and achievable in practice with the right strategy.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity"}]

# Then make the first call:

response = client.messages.create(
    model="claude-3-haiku",
    max_tokens=1000,
    messages=messages
)

# Then read the business idea:

business_idea = response.content[0].text

print (business_idea)

messages = [{"role": "user", "content": business_idea}]

response = client.messages.create(
    model="claude-3-haiku",
    max_tokens=1000,
    messages=messages
)

pain_point = response.content[0].text

print (pain_point)

messages = [{"role": "user", "content": pain_point}]    

response = client.messages.create(
    model="claude-3-haiku",
    max_tokens=1000,
    messages=messages
)   

agentic_solution = response.content[0].text

print (agentic_solution)
# Out:
# **Customer Success/Account Management** seems particularly ripe for Agentic AI exploration.
#
# Here's why this area has strong potential:
#
# ## The Opportunity
# Customer Success teams are overwhelmed trying to:
# - Monitor health scores across hundreds/thousands of accounts
# - Identify at-risk customers before they churn
# - Proactively reach out with relevant solutions
# - Coordinate renewals and expansion opportunities
# - Personalize outreach at scale
#
# ## Why Agentic AI Fits Well
# - **Clear decision points**: When to escalate, what actions to recommend
# - **Defined workflows**: Onboarding sequences, health check protocols
# - **Measurable outcomes**: Retention rates, expansion revenue, time-to-value
# - **Data-rich environment**: Usage analytics, support tickets, engagement metrics
# - **High-value, repetitive tasks**: Perfect for automation with human oversight
#
# ## Potential Agentic Capabilities
# - Automatically detect early warning signs and suggest interventions
# - Generate personalized check-in emails and meeting agendas
# - Coordinate cross-functional responses (support, product, sales)
# - Manage renewal workflows and identify expansion opportunities
# - Create custom success plans based on customer segments
#
# ## Market Reality Check
# - Customer Success is a fast-growing field with clear ROI pressure
# - Teams are already using multiple tools that an agent could orchestrate
# - B2B SaaS companies are desperate to reduce churn and increase expansion
# - Less regulated than areas like finance/healthcare = faster adoption possible
#
# This feels like an area where the technology capability aligns well with genuine business pain points.
# This is a really sharp analysis. Customer Success/Account Management does seem like an ideal beachhead for Agentic AI, and you've identified why the fit is so natural.
#
# What I find particularly compelling about your assessment:
#
# ## The "Goldilocks Zone" Factor
# CS sits in this sweet spot where:
# - The stakes are high enough to justify AI investment (churn is expensive)
# - But not so high that any mistake is catastrophic (unlike medical or financial decisions)
# - The feedback loops are relatively fast (you can see if interventions work within quarters, not years)
#
# ## The Orchestration Opportunity
# Your point about orchestrating existing tools is key. CS teams are already drowning in:
# - CRM data
# - Product usage analytics
# - Support ticket systems
# - Email/communication platforms
# - Billing/revenue data
#
# An agent that can synthesize signals across these systems and take coordinated action could be transformative.
#
# ## Natural Evolution Path
# I can see a clear progression:
# 1. **Start simple**: Automated health score monitoring and basic alerts
# 2. **Add intelligence**: Pattern recognition for churn prediction
# 3. **Enable action**: Automated outreach and workflow coordination
# 4. **Full autonomy**: End-to-end management of low-touch accounts
#
# ## The Timing Advantage
# The macro environment makes this even more attractive:
# - Economic pressure → focus on retention over acquisition
# - Remote work → less intuitive relationship management
# - SaaS maturity → more sophisticated CS operations
#
# Have you seen any companies making serious moves in this direction? I'm curious if the current solutions feel like traditional software or if anyone is building truly agentic approaches.
# You've nailed the strategic logic perfectly. The "Goldilocks Zone" framing is spot-on - CS has that rare combination of high impact and manageable risk that makes it perfect for agentic experimentation.
#
# ## What I'm Seeing in the Market
#
# The landscape is surprisingly fragmented right now:
#
# **Traditional Players Adding AI Veneer**
# - Gainsight, ChurnZero, etc. are bolting on "AI insights"
# - But it's mostly better dashboards, not true agency
# - Still requires humans to interpret and act on everything
#
# **Emerging Agentic Approaches**
# - **Viable** is doing some interesting work on automated customer research/feedback synthesis
# - **Gradient Works** (revenue operations) has agentic elements for pipeline management
# - Several stealth-mode startups I'm tracking that are building truly autonomous CS agents
#
# **The Big Gap**
# Most current solutions are still in the "better analytics" phase. Very few are actually **taking actions** autonomously - sending emails, updating records, triggering workflows, scheduling meetings.
#
# ## The Technical Challenge
# The companies that crack this will need to solve:
# - **Multi-system orchestration** (your point about drowning in tools)
# - **Natural language generation** that doesn't sound robotic
# - **Judgment calls** on when to escalate vs. handle autonomously
# - **Learning loops** that improve from each interaction
#
# ## Where I'd Look for Breakthroughs
# The most promising approaches I've seen combine:
# 1. **Deep CRM integration** (not just reading data, but writing back)
# 2. **Communication AI** that can handle nuanced customer conversations
# 3. **Workflow engines** that can execute multi-step processes
# 4. **Human-in-the-loop design** for gradual trust building
#
# The companies that will win are those building for the full evolution path you outlined - starting simple but architected for full autonomy from day one.
#
# What's your sense of how ready CS leaders are for this shift? The technology is getting there, but adoption might be the real bottleneck.

# %%
from IPython.display import Markdown, display

display(Markdown(business_idea))

display(Markdown(pain_point))

display(Markdown(agentic_solution))
# Out:
# **Customer Success/Account Management** seems particularly ripe for Agentic AI exploration.
#
# Here's why this area has strong potential:
#
# ## The Opportunity
# Customer Success teams are overwhelmed trying to:
# - Monitor health scores across hundreds/thousands of accounts
# - Identify at-risk customers before they churn
# - Proactively reach out with relevant solutions
# - Coordinate renewals and expansion opportunities
# - Personalize outreach at scale
#
# ## Why Agentic AI Fits Well
# - **Clear decision points**: When to escalate, what actions to recommend
# - **Defined workflows**: Onboarding sequences, health check protocols
# - **Measurable outcomes**: Retention rates, expansion revenue, time-to-value
# - **Data-rich environment**: Usage analytics, support tickets, engagement metrics
# - **High-value, repetitive tasks**: Perfect for automation with human oversight
#
# ## Potential Agentic Capabilities
# - Automatically detect early warning signs and suggest interventions
# - Generate personalized check-in emails and meeting agendas
# - Coordinate cross-functional responses (support, product, sales)
# - Manage renewal workflows and identify expansion opportunities
# - Create custom success plans based on customer segments
#
# ## Market Reality Check
# - Customer Success is a fast-growing field with clear ROI pressure
# - Teams are already using multiple tools that an agent could orchestrate
# - B2B SaaS companies are desperate to reduce churn and increase expansion
# - Less regulated than areas like finance/healthcare = faster adoption possible
#
# This feels like an area where the technology capability aligns well with genuine business pain points.
# This is a really sharp analysis. Customer Success/Account Management does seem like an ideal beachhead for Agentic AI, and you've identified why the fit is so natural.
#
# What I find particularly compelling about your assessment:
#
# ## The "Goldilocks Zone" Factor
# CS sits in this sweet spot where:
# - The stakes are high enough to justify AI investment (churn is expensive)
# - But not so high that any mistake is catastrophic (unlike medical or financial decisions)
# - The feedback loops are relatively fast (you can see if interventions work within quarters, not years)
#
# ## The Orchestration Opportunity
# Your point about orchestrating existing tools is key. CS teams are already drowning in:
# - CRM data
# - Product usage analytics
# - Support ticket systems
# - Email/communication platforms
# - Billing/revenue data
#
# An agent that can synthesize signals across these systems and take coordinated action could be transformative.
#
# ## Natural Evolution Path
# I can see a clear progression:
# 1. **Start simple**: Automated health score monitoring and basic alerts
# 2. **Add intelligence**: Pattern recognition for churn prediction
# 3. **Enable action**: Automated outreach and workflow coordination
# 4. **Full autonomy**: End-to-end management of low-touch accounts
#
# ## The Timing Advantage
# The macro environment makes this even more attractive:
# - Economic pressure → focus on retention over acquisition
# - Remote work → less intuitive relationship management
# - SaaS maturity → more sophisticated CS operations
#
# Have you seen any companies making serious moves in this direction? I'm curious if the current solutions feel like traditional software or if anyone is building truly agentic approaches.
# You've nailed the strategic logic perfectly. The "Goldilocks Zone" framing is spot-on - CS has that rare combination of high impact and manageable risk that makes it perfect for agentic experimentation.
#
# ## What I'm Seeing in the Market
#
# The landscape is surprisingly fragmented right now:
#
# **Traditional Players Adding AI Veneer**
# - Gainsight, ChurnZero, etc. are bolting on "AI insights"
# - But it's mostly better dashboards, not true agency
# - Still requires humans to interpret and act on everything
#
# **Emerging Agentic Approaches**
# - **Viable** is doing some interesting work on automated customer research/feedback synthesis
# - **Gradient Works** (revenue operations) has agentic elements for pipeline management
# - Several stealth-mode startups I'm tracking that are building truly autonomous CS agents
#
# **The Big Gap**
# Most current solutions are still in the "better analytics" phase. Very few are actually **taking actions** autonomously - sending emails, updating records, triggering workflows, scheduling meetings.
#
# ## The Technical Challenge
# The companies that crack this will need to solve:
# - **Multi-system orchestration** (your point about drowning in tools)
# - **Natural language generation** that doesn't sound robotic
# - **Judgment calls** on when to escalate vs. handle autonomously
# - **Learning loops** that improve from each interaction
#
# ## Where I'd Look for Breakthroughs
# The most promising approaches I've seen combine:
# 1. **Deep CRM integration** (not just reading data, but writing back)
# 2. **Communication AI** that can handle nuanced customer conversations
# 3. **Workflow engines** that can execute multi-step processes
# 4. **Human-in-the-loop design** for gradual trust building
#
# The companies that will win are those building for the full evolution path you outlined - starting simple but architected for full autonomy from day one.
#
# What's your sense of how ready CS leaders are for this shift? The technology is getting there, but adoption might be the real bottleneck.
